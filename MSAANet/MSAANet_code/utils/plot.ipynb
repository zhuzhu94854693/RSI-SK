# %%
import cv2
import tensorboardX
import torch
from tensorboardX import SummaryWriter
from torch.autograd import Variable
from graphviz import Digraph
import re
import torch
import torch.nn.functional as F
from torch.autograd import Variable
from torchviz import make_dot, make_dot_from_trace

# %%
import sys
sys.path.append('../models/unet/')
from unet import UNet

# %%
image_path = '/home/shiyi/beshe/gaoxin_map/second_dataset/part9_500.png'
label_path = '/home/shiyi/beshe/gaoxin_map/second_dataset/part9_road_500.png'
mask_path = '/home/shiyi/beshe/pytorch_method/model_predict/segnet_predict/0517predict9.png'


picture = cv2.imread(image_path)
Target_mask = cv2.imread(label_path)
vote_mask = cv2.imread(mask_path)

# %%
picture.shape
# Out:
# (8859, 11693, 3)

# %%
image_path = '/home/shiyi/beshe/gaoxin_map/second_dataset/part9_500.png'
label_path = '/home/shiyi/beshe/gaoxin_map/second_dataset/part9_road_500.png'
mask_path = '/home/shiyi/beshe/pytorch_method/model_predict/segnet_predict/0517predict9.png'


picture = cv2.imread(image_path)
Target_mask = cv2.imread(label_path)
vote_mask = cv2.imread(mask_path)
vote_mask = vote_mask[:Target_mask.shape[0],:Target_mask.shape[1]]
vote_mask = vote_mask[0:5000,0:5000]
Target_mask = Target_mask[0:5000,0:5000]
picture = picture[0:5000,0:5000]

# %%
Target_mask = 1-Target_mask
# vote = vote*155
process = picture*Target_mask

# %%
process[process == 0] = [0, 0, 255]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-40a91914693c> in <module>
# ----> 1 process[process == 0] = [0, 0, 255]
#
# ValueError: NumPy boolean array indexing assignment cannot assign 3 input values to the 68594305 output values where the mask is true

# %%
process[process == 0] = [0, 0, 255]
# img_rgb[mask == 255] = 

temp = cv2.resize(process,(1000,1000))
Image.fromarray(temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c15f48262dc9> in <module>
#       1 process = picture*Target_mask
# ----> 2 process[process == 0] = [0, 0, 255]
#       3 # img_rgb[mask == 255] =
#       4
#       5 temp = cv2.resize(process,(1000,1000))
#
# ValueError: NumPy boolean array indexing assignment cannot assign 3 input values to the 7359988 output values where the mask is true

# %%
show = process +vote_mask
show = cv2.resize(show,(1000,1000))

Image.fromarray(show)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F5C3AE6A550>

# %%
Target_mask = 1-Target_mask
process = picture*Target_mask
temp = cv2.resize(process,(1000,1000))
Image.fromarray(temp)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F5C34F8EA20>
